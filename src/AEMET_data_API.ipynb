# %% [markdown]
# # **AEMET API.**

# %% [markdown]
# ## **Importación de librerías.**

# %%
import requests as req
import pandas as pd
import json

# %% [markdown]
# ## **API.**

# %% [markdown]
# ### **Predicción del municipio del día actual.**

# %%
codigos = pd.read_excel('../data/20codmun28.xls')

codigos.head(20)
# Out:
#    Relación de municipios y códigos por provincias a 1 de enero de 2020  \
# 0                                              MADRID
# 1                                                CPRO
# 2                                                  28
# 3                                                  28
# 4                                                  28
# 5                                                  28
# 6                                                  28
# 7                                                  28
# 8                                                  28
# 9                                                  28
# 10                                                 28
# 11                                                 28
# 12                                                 28
# 13                                                 28
# 14                                                 28
# 15                                                 28
# 16                                                 28
# 17                                                 28
# 18                                                 28
# 19                                                 28
#
#    Unnamed: 1 Unnamed: 2             Unnamed: 3
# 0         NaN        NaN                    NaN
# 1        CMUN         DC                 NOMBRE
# 2         001          4            Acebeda, La
# 3         002          9                Ajalvir
# 4         003          5      Alameda del Valle
# 5         004          0              Álamo, El
# 6         005          3      Alcalá de Henares
# 7         006          6             Alcobendas
# 8         007          2               Alcorcón
# 9         008          8       Aldea del Fresno
# 10        009          1                 Algete
# 11        010          5              Alpedrete
# 12        011          2                 Ambite
# 13        012          7               Anchuelo
# 14        013          3               Aranjuez
# 15        014          8        Arganda del Rey
# 16        015          1          Arroyomolinos
# 17        016          4             Atazar, El
# 18        017          0                 Batres
# 19        018          6  Becerril de la Sierra

# %%
# introducir clave API
querystring = {'api_key':'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJhcGFyaWNpb2Zlcm5hbmRlei5kQGdtYWlsLmNvbSIsImp0aSI6IjEwNDY5YzVkLTMwMDUtNDhhMi1hYTU3LTBiM2M2NjE3MmFiOSIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjgzNTAzNTQ3LCJ1c2VySWQiOiIxMDQ2OWM1ZC0zMDA1LTQ4YTItYWE1Ny0wYjNjNjYxNzJhYjkiLCJyb2xlIjoiIn0._fxyjpdUYGVn4fEMEYg64Mvcc5ODJp2J8jLlbUNDtYw'}

# introducir codigo del "municipio"
municipio = '28007'

# fuente de datos para sacar datos climatologicos diarios de una estacion concreta
url = f'https://opendata.aemet.es/opendata/api/prediccion/especifica/municipio/diaria/{municipio}'

headers = {
    'cache-control': "no-cache"
    }

# consultar API
res = req.request('GET', url, headers=headers, params=querystring)

# obtener la URL de descarga de los datos
data_url = res.json()['datos']

# descargar los datos
data_res = req.get(data_url)

# imprimir los datos
print(data_res.text)
# Out:
# [ {
#   "origen" : {
#     "productor" : "Agencia Estatal de Meteorología - AEMET. Gobierno de España",
#     "web" : "https://www.aemet.es",
#     "enlace" : "https://www.aemet.es/es/eltiempo/prediccion/municipios/alcorcon-id28007",
#     "language" : "es",
#     "copyright" : "© AEMET. Autorizado el uso de la información y su reproducción citando a AEMET como autora de la misma.",
#     "notaLegal" : "https://www.aemet.es/es/nota_legal"
#   },
#   "elaborado" : "2023-05-08T13:06:43",
#   "nombre" : "Alcorcón",
#   "provincia" : "Madrid",
#   "prediccion" : {
#     "dia" : [ {
#       "probPrecipitacion" : [ {
#         "value" : 0,
#         "periodo" : "00-24"
#       }, {
#         "value" : 0,
#         "periodo" : "00-12"
#       }, {
#         "value" : 0,
#         "periodo" : "12-24"
#       }, {
#         "value" : 0,
#         "periodo" : "00-06"
#       }, {
#         "value" : 0,
#         "periodo" : "06-12"
#       }, {
#         "value" : 0,
#         "periodo" : "12-18"
#       }, {
#         "value" : 0,
#         "periodo" : "18-24"
#       } ],
#       "cotaNieveProv" : [ {
#         "value" : "",
#         "periodo" : "00-24"
#       }, {
#         "value" : "",
#         "periodo" : "00-12"
#       }, {
#         "value" : "",
#         "periodo" : "12-24"
#       }, {
#         "value" : "",
#         "periodo" : "00-06"
#       }, {
#         "value" : "",
#         "periodo" : "06-12"
#       }, {
#         "value" : "",
#         "periodo" : "12-18"
#       }, {
#         "value" : "",
#         "periodo" : "18-24"
#       } ],
#       "estadoCielo" : [ {
#         "value" : "",
#         "periodo" : "00-24",
#         "descripcion" : ""
#       }, {
#         "value" : "",
#         "periodo" : "00-12",
#         "descripcion" : ""
#       }, {
#         "value" : "17",
#         "periodo" : "12-24",
#         "descripcion" : "Nubes altas"
#       }, {
#         "value" : "",
#         "periodo" : "00-06",
#         "descripcion" : ""
#       }, {
#         "value" : "17",
#         "periodo" : "06-12",
#         "descripcion" : "Nubes altas"
#       }, {
#         "value" : "17",
#         "periodo" : "12-18",
#         "descripcion" : "Nubes altas"
#       }, {
#         "value" : "17",
#         "periodo" : "18-24",
#         "descripcion" : "Nubes altas"
#       } ],
#       "viento" : [ {
#         "direccion" : "",
#         "velocidad" : 0,
#         "periodo" : "00-24"
#       }, {
#         "direccion" : "",
#         "velocidad" : 0,
#         "periodo" : "00-12"
#       }, {
#         "direccion" : "NO",
#         "velocidad" : 15,
#         "periodo" : "12-24"
#       }, {
#         "direccion" : "NE",
#         "velocidad" : 10,
#         "periodo" : "00-06"
#       }, {
#         "direccion" : "O",
#         "velocidad" : 5,
#         "periodo" : "06-12"
#       }, {
#         "direccion" : "NO",
#         "velocidad" : 15,
#         "periodo" : "12-18"
#       }, {
#         "direccion" : "C",
#         "velocidad" : 0,
#         "periodo" : "18-24"
#       } ],
#       "rachaMax" : [ {
#         "value" : "",
#         "periodo" : "00-24"
#       }, {
#         "value" : "",
#         "periodo" : "00-12"
#       }, {
#         "value" : "",
#         "periodo" : "12-24"
#       }, {
#         "value" : "",
#         "periodo" : "00-06"
#       }, {
#         "value" : "",
#         "periodo" : "06-12"
#       }, {
#         "value" : "",
#         "periodo" : "12-18"
#       }, {
#         "value" : "",
#         "periodo" : "18-24"
#       } ],
#       "temperatura" : {
#         "maxima" : 31,
#         "minima" : 12,
#         "dato" : [ {
#           "value" : 13,
#           "hora" : 6
#         }, {
#           "value" : 26,
#           "hora" : 12
#         }, {
#           "value" : 28,
#           "hora" : 18
#         }, {
#           "value" : 19,
#           "hora" : 24
#         } ]
#       },
#       "sensTermica" : {
#         "maxima" : 31,
#         "minima" : 12,
#         "dato" : [ {
#           "value" : 13,
#           "hora" : 6
#         }, {
#           "value" : 26,
#           "hora" : 12
#         }, {
#           "value" : 28,
#           "hora" : 18
#         }, {
#           "value" : 19,
#           "hora" : 24
#         } ]
#       },
#       "humedadRelativa" : {
#         "maxima" : 70,
#         "minima" : 20,
#         "dato" : [ {
#           "value" : 70,
#           "hora" : 6
#         }, {
#           "value" : 30,
#           "hora" : 12
#         }, {
#           "value" : 20,
#           "hora" : 18
#         }, {
#           "value" : 40,
#           "hora" : 24
#         } ]
#       },
#       "uvMax" : 9,
#       "fecha" : "2023-05-08T00:00:00"
#     }, {
#       "probPrecipitacion" : [ {
#         "value" : 0,
#         "periodo" : "00-24"
#       }, {
#         "value" : 0,
#         "periodo" : "00-12"
#       }, {
#         "value" : 0,
#         "periodo" : "12-24"
#       }, {
#         "value" : 0,
#         "periodo" : "00-06"
#       }, {
#         "value" : 0,
#         "periodo" : "06-12"
#       }, {
#         "value" : 0,
#         "periodo" : "12-18"
#       }, {
#         "value" : 0,
#         "periodo" : "18-24"
#       } ],
#       "cotaNieveProv" : [ {
#         "value" : "",
#         "periodo" : "00-24"
#       }, {
#         "value" : "",
#         "periodo" : "00-12"
#       }, {
#         "value" : "",
#         "periodo" : "12-24"
#       }, {
#         "value" : "",
#         "periodo" : "00-06"
#       }, {
#         "value" : "",
#         "periodo" : "06-12"
#       }, {
#         "value" : "",
#         "periodo" : "12-18"
#       }, {
#         "value" : "",
#         "periodo" : "18-24"
#       } ],
#       "estadoCielo" : [ {
#         "value" : "12",
#         "periodo" : "00-24",
#         "descripcion" : "Poco nuboso"
#       }, {
#         "value" : "12",
#         "periodo" : "00-12",
#         "descripcion" : "Poco nuboso"
#       }, {
#         "value" : "11",
#         "periodo" : "12-24",
#         "descripcion" : "Despejado"
#       }, {
#         "value" : "17n",
#         "periodo" : "00-06",
#         "descripcion" : "Nubes altas"
#       }, {
#         "value" : "12",
#         "periodo" : "06-12",
#         "descripcion" : "Poco nuboso"
#       }, {
#         "value" : "11",
#         "periodo" : "12-18",
#         "descripcion" : "Despejado"
#       }, {
#         "value" : "12",
#         "periodo" : "18-24",
#         "descripcion" : "Poco nuboso"
#       } ],
#       "viento" : [ {
#         "direccion" : "NO",
#         "velocidad" : 20,
#         "periodo" : "00-24"
#       }, {
#         "direccion" : "NO",
#         "velocidad" : 20,
#         "periodo" : "00-12"
#       }, {
#         "direccion" : "N",
#         "velocidad" : 20,
#         "periodo" : "12-24"
#       }, {
#         "direccion" : "C",
#         "velocidad" : 0,
#         "periodo" : "00-06"
#       }, {
#         "direccion" : "NO",
#         "velocidad" : 20,
#         "periodo" : "06-12"
#       }, {
#         "direccion" : "N",
#         "velocidad" : 20,
#         "periodo" : "12-18"
#       }, {
#         "direccion" : "NE",
#         "velocidad" : 15,
#         "periodo" : "18-24"
#       } ],
#       "rachaMax" : [ {
#         "value" : "",
#         "periodo" : "00-24"
#       }, {
#         "value" : "",
#         "periodo" : "00-12"
#       }, {
#         "value" : "40",
#         "periodo" : "12-24"
#       }, {
#         "value" : "",
#         "periodo" : "00-06"
#       }, {
#         "value" : "",
#         "periodo" : "06-12"
#       }, {
#         "value" : "40",
#         "periodo" : "12-18"
#       }, {
#         "value" : "",
#         "periodo" : "18-24"
#       } ],
#       "temperatura" : {
#         "maxima" : 29,
#         "minima" : 15,
#         "dato" : [ {
#           "value" : 16,
#           "hora" : 6
#         }, {
#           "value" : 27,
#           "hora" : 12
#         }, {
#           "value" : 25,
#           "hora" : 18
#         }, {
#           "value" : 17,
#           "hora" : 24
#         } ]
#       },
#       "sensTermica" : {
#         "maxima" : 29,
#         "minima" : 15,
#         "dato" : [ {
#           "value" : 16,
#           "hora" : 6
#         }, {
#           "value" : 27,
#           "hora" : 12
#         }, {
#           "value" : 25,
#           "hora" : 18
#         }, {
#           "value" : 17,
#           "hora" : 24
#         } ]
#       },
#       "humedadRelativa" : {
#         "maxima" : 60,
#         "minima" : 25,
#         "dato" : [ {
#           "value" : 50,
#           "hora" : 6
#         }, {
#           "value" : 25,
#           "hora" : 12
#         }, {
#           "value" : 35,
#           "hora" : 18
#         }, {
#           "value" : 60,
#           "hora" : 24
#         } ]
#       },
#       "uvMax" : 9,
#       "fecha" : "2023-05-09T00:00:00"
#     }, {
#       "probPrecipitacion" : [ {
#         "value" : 0,
#         "periodo" : "00-24"
#       }, {
#         "value" : 0,
#         "periodo" : "00-12"
#       }, {
#         "value" : 0,
#         "periodo" : "12-24"
#       } ],
#       "cotaNieveProv" : [ {
#         "value" : "",
#         "periodo" : "00-24"
#       }, {
#         "value" : "",
#         "periodo" : "00-12"
#       }, {
#         "value" : "",
#         "periodo" : "12-24"
#       } ],
#       "estadoCielo" : [ {
#         "value" : "17",
#         "periodo" : "00-24",
#         "descripcion" : "Nubes altas"
#       }, {
#         "value" : "12",
#         "periodo" : "00-12",
#         "descripcion" : "Poco nuboso"
#       }, {
#         "value" : "15",
#         "periodo" : "12-24",
#         "descripcion" : "Muy nuboso"
#       } ],
#       "viento" : [ {
#         "direccion" : "C",
#         "velocidad" : 0,
#         "periodo" : "00-24"
#       }, {
#         "direccion" : "NE",
#         "velocidad" : 15,
#         "periodo" : "00-12"
#       }, {
#         "direccion" : "N",
#         "velocidad" : 15,
#         "periodo" : "12-24"
#       } ],
#       "rachaMax" : [ {
#         "value" : "",
#         "periodo" : "00-24"
#       }, {
#         "value" : "",
#         "periodo" : "00-12"
#       }, {
#         "value" : "",
#         "periodo" : "12-24"
#       } ],
#       "temperatura" : {
#         "maxima" : 26,
#         "minima" : 12,
#         "dato" : [ ]
#       },
#       "sensTermica" : {
#         "maxima" : 26,
#         "minima" : 12,
#         "dato" : [ ]
#       },
#       "humedadRelativa" : {
#         "maxima" : 80,
#         "minima" : 15,
#         "dato" : [ ]
#       },
#       "uvMax" : 9,
#       "fecha" : "2023-05-10T00:00:00"
#     }, {
#       "probPrecipitacion" : [ {
#         "value" : 0,
#         "periodo" : "00-24"
#       }, {
#         "value" : 0,
#         "periodo" : "00-12"
#       }, {
#         "value" : 0,
#         "periodo" : "12-24"
#       } ],
#       "cotaNieveProv" : [ {
#         "value" : "",
#         "periodo" : "00-24"
#       }, {
#         "value" : "",
#         "periodo" : "00-12"
#       }, {
#         "value" : "",
#         "periodo" : "12-24"
#       } ],
#       "estadoCielo" : [ {
#         "value" : "12",
#         "periodo" : "00-24",
#         "descripcion" : "Poco nuboso"
#       }, {
#         "value" : "12",
#         "periodo" : "00-12",
#         "descripcion" : "Poco nuboso"
#       }, {
#         "value" : "11",
#         "periodo" : "12-24",
#         "descripcion" : "Despejado"
#       } ],
#       "viento" : [ {
#         "direccion" : "NE",
#         "velocidad" : 5,
#         "periodo" : "00-24"
#       }, {
#         "direccion" : "NE",
#         "velocidad" : 20,
#         "periodo" : "00-12"
#       }, {
#         "direccion" : "N",
#         "velocidad" : 20,
#         "periodo" : "12-24"
#       } ],
#       "rachaMax" : [ {
#         "value" : "",
#         "periodo" : "00-24"
#       }, {
#         "value" : "",
#         "periodo" : "00-12"
#       }, {
#         "value" : "",
#         "periodo" : "12-24"
#       } ],
#       "temperatura" : {
#         "maxima" : 25,
#         "minima" : 10,
#         "dato" : [ ]
#       },
#       "sensTermica" : {
#         "maxima" : 25,
#         "minima" : 10,
#         "dato" : [ ]
#       },
#       "humedadRelativa" : {
#         "maxima" : 65,
#         "minima" : 15,
#         "dato" : [ ]
#       },
#       "uvMax" : 8,
#       "fecha" : "2023-05-11T00:00:00"
#     }, {
#       "probPrecipitacion" : [ {
#         "value" : 45
#       } ],
#       "cotaNieveProv" : [ {
#         "value" : "1600"
#       } ],
#       "estadoCielo" : [ {
#         "value" : "13",
#         "descripcion" : "Intervalos nubosos"
#       } ],
#       "viento" : [ {
#         "direccion" : "N",
#         "velocidad" : 15
#       } ],
#       "rachaMax" : [ {
#         "value" : ""
#       } ],
#       "temperatura" : {
#         "maxima" : 20,
#         "minima" : 9,
#         "dato" : [ ]
#       },
#       "sensTermica" : {
#         "maxima" : 20,
#         "minima" : 9,
#         "dato" : [ ]
#       },
#       "humedadRelativa" : {
#         "maxima" : 60,
#         "minima" : 30,
#         "dato" : [ ]
#       },
#       "uvMax" : 6,
#       "fecha" : "2023-05-12T00:00:00"
#     }, {
#       "probPrecipitacion" : [ {
#         "value" : 20
#       } ],
#       "cotaNieveProv" : [ {
#         "value" : "1700"
#       } ],
#       "estadoCielo" : [ {
#         "value" : "14",
#         "descripcion" : "Nuboso"
#       } ],
#       "viento" : [ {
#         "direccion" : "NE",
#         "velocidad" : 20
#       } ],
#       "rachaMax" : [ {
#         "value" : ""
#       } ],
#       "temperatura" : {
#         "maxima" : 21,
#         "minima" : 7,
#         "dato" : [ ]
#       },
#       "sensTermica" : {
#         "maxima" : 21,
#         "minima" : 7,
#         "dato" : [ ]
#       },
#       "humedadRelativa" : {
#         "maxima" : 70,
#         "minima" : 25,
#         "dato" : [ ]
#       },
#       "fecha" : "2023-05-13T00:00:00"
#     }, {
#       "probPrecipitacion" : [ {
#         "value" : 10
#       } ],
#       "cotaNieveProv" : [ {
#         "value" : ""
#       } ],
#       "estadoCielo" : [ {
#         "value" : "14",
#         "descripcion" : "Nuboso"
#       } ],
#       "viento" : [ {
#         "direccion" : "N",
#         "velocidad" : 15
#       } ],
#       "rachaMax" : [ {
#         "value" : ""
#       } ],
#       "temperatura" : {
#         "maxima" : 23,
#         "minima" : 6,
#         "dato" : [ ]
#       },
#       "sensTermica" : {
#         "maxima" : 23,
#         "minima" : 6,
#         "dato" : [ ]
#       },
#       "humedadRelativa" : {
#         "maxima" : 80,
#         "minima" : 25,
#         "dato" : [ ]
#       },
#       "fecha" : "2023-05-14T00:00:00"
#     } ]
#   },
#   "id" : 28007,
#   "version" : 1.0
# } ]

# %% [markdown]
# ### **Predicción provincial para mañana.**

# %%
# introducir clave API
querystring = {'api_key':'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJhcGFyaWNpb2Zlcm5hbmRlei5kQGdtYWlsLmNvbSIsImp0aSI6IjEwNDY5YzVkLTMwMDUtNDhhMi1hYTU3LTBiM2M2NjE3MmFiOSIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjgzNTAzNTQ3LCJ1c2VySWQiOiIxMDQ2OWM1ZC0zMDA1LTQ4YTItYWE1Ny0wYjNjNjYxNzJhYjkiLCJyb2xlIjoiIn0._fxyjpdUYGVn4fEMEYg64Mvcc5ODJp2J8jLlbUNDtYw'}

# introducir el codigo de "provincia"
provincia = '28'

# fuente de datos para sacar datos climatologicos diarios de una estacion concreta
url = f'https://opendata.aemet.es/opendata//api/prediccion/provincia/manana/{provincia}'

headers = {
    'cache-control': "no-cache"
    }

# consultar API
res = req.request('GET', url, headers=headers, params=querystring)

# obtener la URL de descarga de los datos
data_url = res.json()['datos']

# descargar los datos
data_res = req.get(data_url)

# imprimir los datos
print(data_res.text)
# Out:
# AGENCIA ESTATAL DE METEOROLOGÍA
# PREDICCIÓN PARA LA PROVINCIA DE MADRID
# DÍA 8 DE MAYO DE 2023 A LAS 14:02 HORA OFICIAL
# PREDICCIÓN VÁLIDA PARA EL MARTES 9
#
# MADRID
# Cielos con intervalos de nubes altas, más abundantes de
# madrugada, y con intervalos de nubes de evolución durante las
# horas centrales del día en el sur de la Comunidad pero también
# en la Sierra, donde además será probable algún chubasco
# tormentoso aislado por la tarde. Temperaturas mínimas en general
# en ascenso, siendo más suave en la Sierra Norte; temperaturas
# máximas con pocos cambios o en descenso ligero, que será algo
# más acusado en la Sierra. Vientos flojos variables de madrugada
# que avanzada la mañana ganarán en intensidad y se harán del
# noroeste, girando progresivamente a noreste a lo largo de la
# jornada y amainando al final.
#
# TEMPERATURAS MÍNIMAS Y MÁXIMAS PREVISTAS (°C):
# Madrid                        16  29
# Alcalá de Henares             13  31
# Getafe                        15  30
# Collado Villalba              14  26
# Navalcarnero                  16  30
# Aranjuez                      14  32

# %% [markdown]
# ### **Valores climatológicos por fechas y estación climatológica.**

# %%
# introducir clave API
querystring = {'api_key':'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJhcGFyaWNpb2Zlcm5hbmRlei5kQGdtYWlsLmNvbSIsImp0aSI6IjEwNDY5YzVkLTMwMDUtNDhhMi1hYTU3LTBiM2M2NjE3MmFiOSIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjgzNTAzNTQ3LCJ1c2VySWQiOiIxMDQ2OWM1ZC0zMDA1LTQ4YTItYWE1Ny0wYjNjNjYxNzJhYjkiLCJyb2xlIjoiIn0._fxyjpdUYGVn4fEMEYg64Mvcc5ODJp2J8jLlbUNDtYw'}

# introducir codigo "IDEMA" (indicador climatologica de la EMA) de la estacion de "Cuatro Vientos"
idema = '3196'

# introducir periodo de consulta en formato AAAAMMDD
fechaIniStr = '2023-04-01T00:00:00UTC'
fechaFinStr = '2023-04-30T23:59:59UTC'

# fuente de datos para sacar datos climatologicos diarios de una estacion concreta
url = f'https://opendata.aemet.es/opendata//api/valores/climatologicos/diarios/datos/fechaini/{fechaIniStr}/fechafin/{fechaFinStr}/estacion/{idema}'

headers = {
    'cache-control': "no-cache"
    }

# consultar API
res = req.request('GET', url, headers=headers, params=querystring)

# obtener la URL de descarga de los datos
data_url = res.json()['datos']

# descargar los datos
data_res = req.get(data_url)

# imprimir los datos
print(data_res.content.decode())
# Out:
# [ {
#   "fecha" : "2023-04-01",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "14,4",
#   "prec" : "0,0",
#   "tmin" : "9,0",
#   "horatmin" : "05:40",
#   "tmax" : "19,9",
#   "horatmax" : "14:30",
#   "dir" : "26",
#   "velmedia" : "5,6",
#   "racha" : "16,1",
#   "horaracha" : "14:00",
#   "sol" : "7,9",
#   "presMax" : "942,8",
#   "horaPresMax" : "07",
#   "presMin" : "939,3",
#   "horaPresMin" : "15"
# }, {
#   "fecha" : "2023-04-02",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "11,6",
#   "prec" : "0,0",
#   "tmin" : "4,2",
#   "horatmin" : "05:10",
#   "tmax" : "19,0",
#   "horatmax" : "16:10",
#   "dir" : "06",
#   "velmedia" : "2,5",
#   "racha" : "8,9",
#   "horaracha" : "13:00",
#   "sol" : "10,3",
#   "presMax" : "945,2",
#   "horaPresMax" : "09",
#   "presMin" : "942,4",
#   "horaPresMin" : "Varias"
# }, {
#   "fecha" : "2023-04-03",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "12,0",
#   "prec" : "0,0",
#   "tmin" : "4,0",
#   "horatmin" : "05:40",
#   "tmax" : "20,0",
#   "horatmax" : "16:10",
#   "dir" : "22",
#   "velmedia" : "1,9",
#   "racha" : "7,2",
#   "horaracha" : "16:40",
#   "sol" : "9,9",
#   "presMax" : "943,2",
#   "horaPresMax" : "00",
#   "presMin" : "933,4",
#   "horaPresMin" : "Varias"
# }, {
#   "fecha" : "2023-04-04",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "13,8",
#   "prec" : "0,0",
#   "tmin" : "7,0",
#   "horatmin" : "05:45",
#   "tmax" : "20,7",
#   "horatmax" : "Varias",
#   "dir" : "08",
#   "velmedia" : "3,6",
#   "racha" : "12,5",
#   "horaracha" : "15:10",
#   "sol" : "11,3",
#   "presMax" : "938,8",
#   "horaPresMax" : "24",
#   "presMin" : "932,8",
#   "horaPresMin" : "03"
# }, {
#   "fecha" : "2023-04-05",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "13,2",
#   "prec" : "0,0",
#   "tmin" : "4,2",
#   "horatmin" : "05:40",
#   "tmax" : "22,1",
#   "horatmax" : "Varias",
#   "dir" : "07",
#   "velmedia" : "1,1",
#   "racha" : "7,8",
#   "horaracha" : "09:30",
#   "sol" : "10,8",
#   "presMax" : "940,0",
#   "horaPresMax" : "09",
#   "presMin" : "935,8",
#   "horaPresMin" : "Varias"
# }, {
#   "fecha" : "2023-04-06",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "16,6",
#   "prec" : "0,0",
#   "tmin" : "9,1",
#   "horatmin" : "05:50",
#   "tmax" : "24,1",
#   "horatmax" : "15:20",
#   "dir" : "10",
#   "velmedia" : "1,7",
#   "racha" : "5,6",
#   "horaracha" : "11:20",
#   "sol" : "10,7",
#   "presMax" : "939,3",
#   "horaPresMax" : "09",
#   "presMin" : "936,2",
#   "horaPresMin" : "17"
# }, {
#   "fecha" : "2023-04-07",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "16,4",
#   "prec" : "0,0",
#   "tmin" : "8,0",
#   "horatmin" : "05:55",
#   "tmax" : "24,7",
#   "horatmax" : "Varias",
#   "dir" : "20",
#   "velmedia" : "2,5",
#   "racha" : "8,9",
#   "horaracha" : "13:30",
#   "sol" : "10,3",
#   "presMax" : "938,4",
#   "horaPresMax" : "07",
#   "presMin" : "934,8",
#   "horaPresMin" : "16"
# }, {
#   "fecha" : "2023-04-08",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "17,4",
#   "prec" : "0,0",
#   "tmin" : "8,8",
#   "horatmin" : "06:15",
#   "tmax" : "26,0",
#   "horatmax" : "15:15",
#   "dir" : "22",
#   "velmedia" : "1,7",
#   "racha" : "7,8",
#   "horaracha" : "13:30",
#   "sol" : "10,8",
#   "presMax" : "938,5",
#   "horaPresMax" : "09",
#   "presMin" : "936,0",
#   "horaPresMin" : "15"
# }, {
#   "fecha" : "2023-04-09",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "18,9",
#   "prec" : "0,0",
#   "tmin" : "10,5",
#   "horatmin" : "06:00",
#   "tmax" : "27,3",
#   "horatmax" : "Varias",
#   "dir" : "26",
#   "velmedia" : "3,3",
#   "racha" : "9,7",
#   "horaracha" : "13:40",
#   "sol" : "9,2",
#   "presMax" : "942,0",
#   "horaPresMax" : "22",
#   "presMin" : "938,0",
#   "horaPresMin" : "00"
# }, {
#   "fecha" : "2023-04-10",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "20,3",
#   "prec" : "0,0",
#   "tmin" : "13,2",
#   "horatmin" : "05:50",
#   "tmax" : "27,4",
#   "horatmax" : "15:30",
#   "dir" : "23",
#   "velmedia" : "1,9",
#   "racha" : "11,4",
#   "horaracha" : "14:50",
#   "sol" : "8,8",
#   "presMax" : "943,6",
#   "horaPresMax" : "10",
#   "presMin" : "941,2",
#   "horaPresMin" : "02"
# }, {
#   "fecha" : "2023-04-11",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "18,6",
#   "prec" : "0,0",
#   "tmin" : "10,8",
#   "horatmin" : "05:50",
#   "tmax" : "26,4",
#   "horatmax" : "15:30",
#   "dir" : "23",
#   "velmedia" : "4,2",
#   "racha" : "11,4",
#   "horaracha" : "16:20",
#   "sol" : "10,3",
#   "presMax" : "943,3",
#   "horaPresMax" : "00",
#   "presMin" : "937,4",
#   "horaPresMin" : "24"
# }, {
#   "fecha" : "2023-04-12",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "14,6",
#   "prec" : "0,2",
#   "tmin" : "9,4",
#   "horatmin" : "06:15",
#   "tmax" : "19,9",
#   "horatmax" : "11:40",
#   "dir" : "26",
#   "velmedia" : "3,9",
#   "racha" : "13,3",
#   "horaracha" : "17:20",
#   "sol" : "7,0",
#   "presMax" : "937,4",
#   "horaPresMax" : "00",
#   "presMin" : "933,8",
#   "horaPresMin" : "17"
# }, {
#   "fecha" : "2023-04-13",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "11,8",
#   "prec" : "0,0",
#   "tmin" : "6,5",
#   "horatmin" : "05:45",
#   "tmax" : "17,0",
#   "horatmax" : "15:15",
#   "dir" : "29",
#   "velmedia" : "4,4",
#   "racha" : "12,8",
#   "horaracha" : "01:10",
#   "sol" : "10,9",
#   "presMax" : "940,0",
#   "horaPresMax" : "Varias",
#   "presMin" : "936,3",
#   "horaPresMin" : "01"
# }, {
#   "fecha" : "2023-04-14",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "13,5",
#   "prec" : "0,0",
#   "tmin" : "7,0",
#   "horatmin" : "05:20",
#   "tmax" : "20,0",
#   "horatmax" : "16:30",
#   "dir" : "28",
#   "velmedia" : "4,7",
#   "racha" : "16,4",
#   "horaracha" : "21:00",
#   "sol" : "8,5",
#   "presMax" : "940,0",
#   "horaPresMax" : "23",
#   "presMin" : "937,0",
#   "horaPresMin" : "16"
# }, {
#   "fecha" : "2023-04-15",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "16,7",
#   "prec" : "0,0",
#   "tmin" : "9,7",
#   "horatmin" : "06:10",
#   "tmax" : "23,7",
#   "horatmax" : "15:50",
#   "dir" : "32",
#   "velmedia" : "2,2",
#   "racha" : "11,9",
#   "horaracha" : "02:50",
#   "sol" : "12,4",
#   "presMax" : "942,0",
#   "horaPresMax" : "22",
#   "presMin" : "939,3",
#   "horaPresMin" : "02"
# }, {
#   "fecha" : "2023-04-16",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "17,4",
#   "prec" : "0,0",
#   "tmin" : "10,0",
#   "horatmin" : "05:30",
#   "tmax" : "24,8",
#   "horatmax" : "15:30",
#   "dir" : "02",
#   "velmedia" : "2,8",
#   "racha" : "12,5",
#   "horaracha" : "02:30",
#   "sol" : "12,3",
#   "presMax" : "942,2",
#   "horaPresMax" : "07",
#   "presMin" : "937,3",
#   "horaPresMin" : "Varias"
# }, {
#   "fecha" : "2023-04-17",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "17,4",
#   "prec" : "0,0",
#   "tmin" : "9,3",
#   "horatmin" : "05:50",
#   "tmax" : "25,5",
#   "horatmax" : "Varias",
#   "dir" : "04",
#   "velmedia" : "2,2",
#   "racha" : "10,3",
#   "horaracha" : "22:40",
#   "sol" : "12,4",
#   "presMax" : "938,0",
#   "horaPresMax" : "Varias",
#   "presMin" : "932,6",
#   "horaPresMin" : "17"
# }, {
#   "fecha" : "2023-04-18",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "16,4",
#   "prec" : "0,0",
#   "tmin" : "9,5",
#   "horatmin" : "05:50",
#   "tmax" : "23,2",
#   "horatmax" : "15:30",
#   "dir" : "10",
#   "velmedia" : "2,5",
#   "racha" : "9,2",
#   "horaracha" : "22:30",
#   "sol" : "12,2",
#   "presMax" : "934,8",
#   "horaPresMax" : "00",
#   "presMin" : "930,4",
#   "horaPresMin" : "17"
# }, {
#   "fecha" : "2023-04-19",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "17,4",
#   "prec" : "0,0",
#   "tmin" : "10,3",
#   "horatmin" : "05:45",
#   "tmax" : "24,6",
#   "horatmax" : "16:50",
#   "dir" : "12",
#   "velmedia" : "1,9",
#   "racha" : "12,5",
#   "horaracha" : "00:10",
#   "sol" : "12,2",
#   "presMax" : "935,1",
#   "horaPresMax" : "08",
#   "presMin" : "931,6",
#   "horaPresMin" : "18"
# }, {
#   "fecha" : "2023-04-20",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "19,0",
#   "prec" : "0,0",
#   "tmin" : "10,6",
#   "horatmin" : "05:50",
#   "tmax" : "27,4",
#   "horatmax" : "15:30",
#   "dir" : "26",
#   "velmedia" : "3,9",
#   "racha" : "11,4",
#   "horaracha" : "15:20",
#   "sol" : "11,4",
#   "presMax" : "933,1",
#   "horaPresMax" : "00",
#   "presMin" : "928,5",
#   "horaPresMin" : "17"
# }, {
#   "fecha" : "2023-04-21",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "18,3",
#   "prec" : "7,0",
#   "tmin" : "11,0",
#   "horatmin" : "05:50",
#   "tmax" : "25,6",
#   "horatmax" : "14:50",
#   "dir" : "23",
#   "velmedia" : "3,9",
#   "racha" : "13,3",
#   "horaracha" : "14:10",
#   "sol" : "9,3",
#   "presMax" : "929,6",
#   "horaPresMax" : "24",
#   "presMin" : "925,7",
#   "horaPresMin" : "16"
# }, {
#   "fecha" : "2023-04-22",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "16,1",
#   "prec" : "0,1",
#   "tmin" : "11,2",
#   "horatmin" : "05:55",
#   "tmax" : "21,0",
#   "horatmax" : "16:00",
#   "dir" : "24",
#   "velmedia" : "4,4",
#   "racha" : "11,9",
#   "horaracha" : "10:30",
#   "sol" : "9,4",
#   "presMax" : "936,1",
#   "horaPresMax" : "24",
#   "presMin" : "929,4",
#   "horaPresMin" : "Varias"
# }, {
#   "fecha" : "2023-04-23",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "16,8",
#   "prec" : "0,0",
#   "tmin" : "9,5",
#   "horatmin" : "05:40",
#   "tmax" : "24,0",
#   "horatmax" : "14:20",
#   "dir" : "31",
#   "velmedia" : "4,2",
#   "racha" : "10,8",
#   "horaracha" : "23:59",
#   "sol" : "12,0",
#   "presMax" : "937,9",
#   "horaPresMax" : "23",
#   "presMin" : "935,0",
#   "horaPresMin" : "15"
# }, {
#   "fecha" : "2023-04-24",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "18,5",
#   "prec" : "0,0",
#   "tmin" : "11,2",
#   "horatmin" : "05:50",
#   "tmax" : "25,8",
#   "horatmax" : "15:50",
#   "dir" : "26",
#   "velmedia" : "2,2",
#   "racha" : "11,4",
#   "horaracha" : "13:50",
#   "sol" : "11,0",
#   "presMax" : "939,2",
#   "horaPresMax" : "07",
#   "presMin" : "936,2",
#   "horaPresMin" : "17"
# }, {
#   "fecha" : "2023-04-25",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "20,8",
#   "prec" : "0,0",
#   "tmin" : "13,0",
#   "horatmin" : "05:15",
#   "tmax" : "28,6",
#   "horatmax" : "15:30",
#   "dir" : "25",
#   "velmedia" : "3,3",
#   "racha" : "9,2",
#   "horaracha" : "14:30",
#   "sol" : "12,4",
#   "presMax" : "938,0",
#   "horaPresMax" : "Varias",
#   "presMin" : "935,3",
#   "horaPresMin" : "17"
# }, {
#   "fecha" : "2023-04-26",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "21,9",
#   "prec" : "0,0",
#   "tmin" : "14,2",
#   "horatmin" : "05:30",
#   "tmax" : "29,6",
#   "horatmax" : "15:30",
#   "dir" : "22",
#   "velmedia" : "3,9",
#   "racha" : "10,8",
#   "horaracha" : "14:40",
#   "sol" : "11,5",
#   "presMax" : "937,6",
#   "horaPresMax" : "09",
#   "presMin" : "934,8",
#   "horaPresMin" : "16"
# }, {
#   "fecha" : "2023-04-27",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "23,6",
#   "prec" : "0,0",
#   "tmin" : "15,8",
#   "horatmin" : "04:50",
#   "tmax" : "31,4",
#   "horatmax" : "15:30",
#   "dir" : "22",
#   "velmedia" : "2,5",
#   "racha" : "10,3",
#   "horaracha" : "15:40",
#   "sol" : "10,3",
#   "presMax" : "937,7",
#   "horaPresMax" : "09",
#   "presMin" : "934,9",
#   "horaPresMin" : "Varias"
# }, {
#   "fecha" : "2023-04-28",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "25,2",
#   "prec" : "0,0",
#   "tmin" : "18,5",
#   "horatmin" : "05:00",
#   "tmax" : "31,8",
#   "horatmax" : "12:50",
#   "dir" : "26",
#   "velmedia" : "3,3",
#   "racha" : "11,4",
#   "horaracha" : "15:30",
#   "sol" : "5,4",
#   "presMax" : "937,1",
#   "horaPresMax" : "10",
#   "presMin" : "934,7",
#   "horaPresMin" : "03"
# }, {
#   "fecha" : "2023-04-29",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "21,6",
#   "prec" : "Ip",
#   "tmin" : "16,8",
#   "horatmin" : "05:30",
#   "tmax" : "26,5",
#   "horatmax" : "15:45",
#   "dir" : "26",
#   "velmedia" : "3,6",
#   "racha" : "12,5",
#   "horaracha" : "16:10",
#   "sol" : "5,4",
#   "presMax" : "939,1",
#   "horaPresMax" : "23",
#   "presMin" : "935,6",
#   "horaPresMin" : "01"
# }, {
#   "fecha" : "2023-04-30",
#   "indicativo" : "3196",
#   "nombre" : "MADRID, CUATRO VIENTOS",
#   "provincia" : "MADRID",
#   "altitud" : "690",
#   "tmed" : "19,6",
#   "prec" : "0,0",
#   "tmin" : "13,8",
#   "horatmin" : "06:50",
#   "tmax" : "25,4",
#   "horatmax" : "16:00",
#   "dir" : "04",
#   "velmedia" : "2,5",
#   "racha" : "9,2",
#   "horaracha" : "21:20",
#   "sol" : "7,3",
#   "presMax" : "940,3",
#   "horaPresMax" : "09",
#   "presMin" : "936,6",
#   "horaPresMin" : "18"
# } ]

# %%
data_dict = json.loads(data_res.content)
clima_dia_abr23_df = pd.DataFrame(data_dict)

clima_dia_abr23_df
# Out:
#          fecha indicativo                  nombre provincia altitud  tmed  \
# 0   2023-04-01       3196  MADRID, CUATRO VIENTOS    MADRID     690  14,4
# 1   2023-04-02       3196  MADRID, CUATRO VIENTOS    MADRID     690  11,6
# 2   2023-04-03       3196  MADRID, CUATRO VIENTOS    MADRID     690  12,0
# 3   2023-04-04       3196  MADRID, CUATRO VIENTOS    MADRID     690  13,8
# 4   2023-04-05       3196  MADRID, CUATRO VIENTOS    MADRID     690  13,2
# 5   2023-04-06       3196  MADRID, CUATRO VIENTOS    MADRID     690  16,6
# 6   2023-04-07       3196  MADRID, CUATRO VIENTOS    MADRID     690  16,4
# 7   2023-04-08       3196  MADRID, CUATRO VIENTOS    MADRID     690  17,4
# 8   2023-04-09       3196  MADRID, CUATRO VIENTOS    MADRID     690  18,9
# 9   2023-04-10       3196  MADRID, CUATRO VIENTOS    MADRID     690  20,3
# 10  2023-04-11       3196  MADRID, CUATRO VIENTOS    MADRID     690  18,6
# 11  2023-04-12       3196  MADRID, CUATRO VIENTOS    MADRID     690  14,6
# 12  2023-04-13       3196  MADRID, CUATRO VIENTOS    MADRID     690  11,8
# 13  2023-04-14       3196  MADRID, CUATRO VIENTOS    MADRID     690  13,5
# 14  2023-04-15       3196  MADRID, CUATRO VIENTOS    MADRID     690  16,7
# 15  2023-04-16       3196  MADRID, CUATRO VIENTOS    MADRID     690  17,4
# 16  2023-04-17       3196  MADRID, CUATRO VIENTOS    MADRID     690  17,4
# 17  2023-04-18       3196  MADRID, CUATRO VIENTOS    MADRID     690  16,4
# 18  2023-04-19       3196  MADRID, CUATRO VIENTOS    MADRID     690  17,4
# 19  2023-04-20       3196  MADRID, CUATRO VIENTOS    MADRID     690  19,0
# 20  2023-04-21       3196  MADRID, CUATRO VIENTOS    MADRID     690  18,3
# 21  2023-04-22       3196  MADRID, CUATRO VIENTOS    MADRID     690  16,1
# 22  2023-04-23       3196  MADRID, CUATRO VIENTOS    MADRID     690  16,8
# 23  2023-04-24       3196  MADRID, CUATRO VIENTOS    MADRID     690  18,5
# 24  2023-04-25       3196  MADRID, CUATRO VIENTOS    MADRID     690  20,8
# 25  2023-04-26       3196  MADRID, CUATRO VIENTOS    MADRID     690  21,9
# 26  2023-04-27       3196  MADRID, CUATRO VIENTOS    MADRID     690  23,6
# 27  2023-04-28       3196  MADRID, CUATRO VIENTOS    MADRID     690  25,2
# 28  2023-04-29       3196  MADRID, CUATRO VIENTOS    MADRID     690  21,6
# 29  2023-04-30       3196  MADRID, CUATRO VIENTOS    MADRID     690  19,6
#
#    prec  tmin horatmin  tmax horatmax dir velmedia racha horaracha   sol  \
# 0   0,0   9,0    05:40  19,9    14:30  26      5,6  16,1     14:00   7,9
# 1   0,0   4,2    05:10  19,0    16:10  06      2,5   8,9     13:00  10,3
# 2   0,0   4,0    05:40  20,0    16:10  22      1,9   7,2     16:40   9,9
# 3   0,0   7,0    05:45  20,7   Varias  08      3,6  12,5     15:10  11,3
# 4   0,0   4,2    05:40  22,1   Varias  07      1,1   7,8     09:30  10,8
# 5   0,0   9,1    05:50  24,1    15:20  10      1,7   5,6     11:20  10,7
# 6   0,0   8,0    05:55  24,7   Varias  20      2,5   8,9     13:30  10,3
# 7   0,0   8,8    06:15  26,0    15:15  22      1,7   7,8     13:30  10,8
# 8   0,0  10,5    06:00  27,3   Varias  26      3,3   9,7     13:40   9,2
# 9   0,0  13,2    05:50  27,4    15:30  23      1,9  11,4     14:50   8,8
# 10  0,0  10,8    05:50  26,4    15:30  23      4,2  11,4     16:20  10,3
# 11  0,2   9,4    06:15  19,9    11:40  26      3,9  13,3     17:20   7,0
# 12  0,0   6,5    05:45  17,0    15:15  29      4,4  12,8     01:10  10,9
# 13  0,0   7,0    05:20  20,0    16:30  28      4,7  16,4     21:00   8,5
# 14  0,0   9,7    06:10  23,7    15:50  32      2,2  11,9     02:50  12,4
# 15  0,0  10,0    05:30  24,8    15:30  02      2,8  12,5     02:30  12,3
# 16  0,0   9,3    05:50  25,5   Varias  04      2,2  10,3     22:40  12,4
# 17  0,0   9,5    05:50  23,2    15:30  10      2,5   9,2     22:30  12,2
# 18  0,0  10,3    05:45  24,6    16:50  12      1,9  12,5     00:10  12,2
# 19  0,0  10,6    05:50  27,4    15:30  26      3,9  11,4     15:20  11,4
# 20  7,0  11,0    05:50  25,6    14:50  23      3,9  13,3     14:10   9,3
# 21  0,1  11,2    05:55  21,0    16:00  24      4,4  11,9     10:30   9,4
# 22  0,0   9,5    05:40  24,0    14:20  31      4,2  10,8     23:59  12,0
# 23  0,0  11,2    05:50  25,8    15:50  26      2,2  11,4     13:50  11,0
# 24  0,0  13,0    05:15  28,6    15:30  25      3,3   9,2     14:30  12,4
# 25  0,0  14,2    05:30  29,6    15:30  22      3,9  10,8     14:40  11,5
# 26  0,0  15,8    04:50  31,4    15:30  22      2,5  10,3     15:40  10,3
# 27  0,0  18,5    05:00  31,8    12:50  26      3,3  11,4     15:30   5,4
# 28   Ip  16,8    05:30  26,5    15:45  26      3,6  12,5     16:10   5,4
# 29  0,0  13,8    06:50  25,4    16:00  04      2,5   9,2     21:20   7,3
#
#    presMax horaPresMax presMin horaPresMin
# 0    942,8          07   939,3          15
# 1    945,2          09   942,4      Varias
# 2    943,2          00   933,4      Varias
# 3    938,8          24   932,8          03
# 4    940,0          09   935,8      Varias
# 5    939,3          09   936,2          17
# 6    938,4          07   934,8          16
# 7    938,5          09   936,0          15
# 8    942,0          22   938,0          00
# 9    943,6          10   941,2          02
# 10   943,3          00   937,4          24
# 11   937,4          00   933,8          17
# 12   940,0      Varias   936,3          01
# 13   940,0          23   937,0          16
# 14   942,0          22   939,3          02
# 15   942,2          07   937,3      Varias
# 16   938,0      Varias   932,6          17
# 17   934,8          00   930,4          17
# 18   935,1          08   931,6          18
# 19   933,1          00   928,5          17
# 20   929,6          24   925,7          16
# 21   936,1          24   929,4      Varias
# 22   937,9          23   935,0          15
# 23   939,2          07   936,2          17
# 24   938,0      Varias   935,3          17
# 25   937,6          09   934,8          16
# 26   937,7          09   934,9      Varias
# 27   937,1          10   934,7          03
# 28   939,1          23   935,6          01
# 29   940,3          09   936,6          18
